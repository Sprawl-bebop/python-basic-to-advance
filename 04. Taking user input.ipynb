# %%
msg = input()
# Out:
# helllo

# %%
print(msg)
# Out:
# helllo

# %%
name = input("Enter your name\n")
print(f"Name is : {name}")
# Out:
# Enter your name
# ashrit
# Name is : ashrit

# %%
num1 = int(input("num1: "))
num2 = int(input("num2: "))
sum = num1 + num2
print(f"sum = {sum}")
# Out:
# num1: 45
# num2: 45
# sum = 90
