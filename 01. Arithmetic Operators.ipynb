# %%
a = 34
b = 87
c = a + b
print(f"Sum: {c}")
# Out:
# Sum: 121

# %% [markdown]
# # Addition operator
# * `a`, `b`, and `c` are user defined variables.
# * `a` and `b` are assigned with integer values 34 and 87 respectively.
# * Using addition operator `+`, the sum of `a` and `b` is calculated and is assigned to `c`.
# * Result is printed as `Sum: 121`.

# %%
a = 64
b = 23
c = a - b
print(f"Difference: {c}")
# Out:
# Difference: 41

# %% [markdown]
# # Subtraction operator
# * `a`, `b`, and `c` are user defined variables.
# * `a` and `b` are assigned with integer values 64 and 23 respectively.
# * Using subtraction operator `-`, the difference of `a` and `b` is calculated and is stored in `c`.
# * Result is printed as `Difference: 41`.

# %%
a = 12
b = 9
c = a * b
print(f"Product: {c}")
# Out:
# Product: 108

# %% [markdown]
# # Multiplication operator
# * `a`, `b`, and `c` are user defined variables.
# * `a` and `b` are assigned with integer values 12 and 9 respectively.
# * Using multiplication operator `*`, the product of `a` and `b` is calculated and is stored in `c`.
# * Result is printed as `Product: 108`.

# %%
a = 33
b = 11
c = a / b
print(f"Result: {c}")
# Out:
# Result: 3.0

# %% [markdown]
# # Division operator
# * `a`, `b`, and `c` are user defined variables.
# * `a` and `b` are assigned with integer values 33 and 11 respectively.
# * Using division operator `/`, the result of `a` divided by `b` is calculated and is stored in `c`.
# * Result is printed as `Result: 3.0`.

# %%
a = 41
b = 3
c = a % b
print(f"Remainder: {c}")
# Out:
# Remainder: 2

# %% [markdown]
# # Modulus operator
# * `a`, `b`, and `c` are user defined variables.
# * `a` and `b` are assigned with integer values 41 and 3 respectively.
# * Modulus operator is used to find the remainder after division.
# * Using modulus operator `%`, the remainder of `a` divided by `b` is calculated and is stored in `c`.
# * Result is printed as `Remainder: 2`.

# %%
a = 41
b = 3
c = a // b
print(f"Floor value: {c}")
# Out:
# Floor value: 13

# %% [markdown]
# # Floor Division operator
# * `a`, `b`, and `c` are user defined variables.
# * `a` and `b` are assigned with integer values 41 and 3 respectively.
# * Floor division operator is used to find the nearest ceiling or integer value excluding values after decimal.
# * Using floor division operator `//`, the nearest integer value of `a` divided by `b` is calculated and is stored in `c`. Values after decimal are excluded.
# * Result is printed as `Floor value: 13`.

# %%
a = 3
b = 4
c = a ** b
print(f"Result: {c}")
# Out:
# Result: 81

# %% [markdown]
# # Power operator
# * `a`, `b`, and `c` are user defined variables.
# * `a` and `b` are assigned with integer values 3 and 4 respectively.
# * Power operator is used to find power of the given variables.
# * Using power operator `**`, the power of `a` raised by `b` ie `a^b` is calculated and is stored in `c`.
# * Result is printed as `Result: 81`.
